# %%
# Importing Data
import pandas as pd
import numpy as np
import os

# %%
# Define Path

path=r'/Users/marieanek2/Documents/Instacart Basket Analysis'

# %%
# Data set Prior Orders
df_ords_prior= pd.read_csv(os.path.join(path,'02 Data','Original Data','order_products_prior.csv'),index_col = False)

# %%
# Data set Orders
df_ords= pd.read_csv(os.path.join(path,'02 Data','Original Data','orders.csv'),index_col = False)

# %%
# 3. In a new notebook, import the orders_products_combined dataframe from the pickle file you just saved.
df_orders_products_combined = pd.read_pickle(r'/Users/marieanek2/Documents/Instacart Basket Analysis/02 Data/Prepared Data/orders_products_combined.pkl')

# %%
# 4. Check the shape of the imported dataframe (it should be the same as the one you exported—always check!).
df_orders_products_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN       196.0                1.0        0.0   both
# 1                     NaN     14084.0                2.0        0.0   both
# 2                     NaN     12427.0                3.0        0.0   both
# 3                     NaN     26088.0                4.0        0.0   both
# 4                     NaN     26405.0                5.0        0.0   both

# %%
df_orders_products_combined.shape
# Out:
# (32640698, 11)

# %%
# Data set Products
df_prods= pd.read_csv(os.path.join(path,'02 Data','Original Data','products.csv'),index_col = False)

# %%
df_orders_products_combined_1 = df_orders_products_combined.drop(columns = ['_merge'])

# %%
# 5. Determine a suitable way to combine the orders_products_combined dataframe with your products data set. Make sure you’re using your wrangled, cleaned, and deduped products data set stored in your “Prepared Data” folder from the previous Exercise’s task.
orders_products_merged = df_orders_products_combined_1.merge(df_prods, on = ['product_id'], how = 'left',indicator = True)

# %%
orders_products_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN       196.0                1.0        0.0
# 1                     NaN     14084.0                2.0        0.0
# 2                     NaN     12427.0                3.0        0.0
# 3                     NaN     26088.0                4.0        0.0
# 4                     NaN     26405.0                5.0        0.0
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda      77.0            7.0     9.0
# 1  Organic Unsweetened Vanilla Almond Milk      91.0           16.0    12.5
# 2                      Original Beef Jerky      23.0           19.0     4.4
# 3               Aged White Cheddar Popcorn      23.0           19.0     4.7
# 4         XL Pick-A-Size Paper Towel Rolls      54.0           17.0     1.0
#
#   _merge
# 0   both
# 1   both
# 2   both
# 3   both
# 4   both

# %%
orders_products_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN       196.0                1.0        0.0
# 1                     NaN     14084.0                2.0        0.0
# 2                     NaN     12427.0                3.0        0.0
# 3                     NaN     26088.0                4.0        0.0
# 4                     NaN     26405.0                5.0        0.0
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda      77.0            7.0     9.0
# 1  Organic Unsweetened Vanilla Almond Milk      91.0           16.0    12.5
# 2                      Original Beef Jerky      23.0           19.0     4.4
# 3               Aged White Cheddar Popcorn      23.0           19.0     4.7
# 4         XL Pick-A-Size Paper Towel Rolls      54.0           17.0     1.0
#
#   _merge
# 0   both
# 1   both
# 2   both
# 3   both
# 4   both

# %%
# 6. Confirm the results of the merge using the merge flag.
orders_products_merged['_merge'].value_counts()
# Out:
# both          32434212
# left_only       208238
# right_only           0
# Name: _merge, dtype: int64

# %%
# 7. Export the newly created dataframe as orders_products_merged in a suitable format (taking into consideration the size).
orders_products_merged.to_pickle(r'/Users/marieanek2/Documents/Instacart Basket Analysis/02 Data/Prepared Data/orders_products_merged.pkl')
